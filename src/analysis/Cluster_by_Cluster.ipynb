# %%
from helpers.topic_by_topic import make_topic_file,\
                                   make_figure_output,\
                                   make_descriptives
make_topic_file()

# %%
make_figure_output('2.')

# %%
make_descriptives('2.')
# Out:
# Number of ICS:  344
# Distribution Across UoAs: UoA 76 (32.0), UoA 50 (28.0), UoA 30 (15.0), UoA 27 (34.0), UoA 25 (27.0), UoA 24 (33.0), UoA 22 (26.0), UoA 20 (31.0), UoA 18 (29.0), UoA 10 (23.0), UoA 7 (25.0), UoA 7 (13.0), UoA 6 (30.0), UoA 5 (14.0), UoA 5 (22.0), UoA 4 (19.0), UoA 3 (17.0), UoA 3 (18.0), UoA 1 (4.0), UoA 1 (20.0)
# The most frequent funder is: Arts and Humanities Research Council [GBR](110). The second most is: Leverhulme Trust(41).
# The most frequent country beneficiary is : GBR(221). The second most is: USA(55).
# The most frequent regional beneficiary is : global (14). The second most is: europe (5).
# ...

# %%
make_figure_output('9.')

# %%
make_descriptives('9.')
# Out:
# Number of ICS:  493
# Distribution Across UoAs: UoA 139 (24.0), UoA 128 (4.0), UoA 61 (17.0), UoA 25 (23.0), UoA 23 (20.0), UoA 20 (30.0), UoA 11 (18.0), UoA 11 (21.0), UoA 10 (16.0), UoA 8 (28.0), UoA 8 (19.0), UoA 8 (26.0), UoA 7 (27.0), UoA 7 (34.0), UoA 6 (32.0), UoA 6 (14.0), UoA 4 (13.0), UoA 3 (22.0), UoA 3 (31.0), UoA 2 (25.0), UoA 2 (33.0), UoA 1 (15.0)
# The most frequent funder is: National Institute for Health and Care Research [GBR](68). The second most is: Economic and Social Research Council [GBR](61).
# The most frequent country beneficiary is : GBR(293). The second most is: USA(76).
# The most frequent regional beneficiary is : global (42). The second most is: europe (18).
# The five most common interdisciplinarities are: Biomedical And Clinical Sciences; Health Sciences (85), Health Sciences; Biomedical And Clinical Sciences (85), Psychology; Biomedical And Clinical Sciences (47), Biomedical And Clinical Sciences; Psychology (47), Health Sciences; Psychology (20).
# ...

# %%
make_figure_output('10.')

# %%
make_descriptives('10.')
# Out:
# Number of ICS:  267
# Distribution Across UoAs: UoA 81 (14.0), UoA 53 (13.0), UoA 45 (17.0), UoA 16 (32.0), UoA 13 (4.0), UoA 8 (22.0), UoA 8 (18.0), UoA 7 (21.0), UoA 7 (16.0), UoA 6 (20.0), UoA 6 (19.0), UoA 4 (30.0), UoA 4 (28.0), UoA 4 (15.0), UoA 2 (23.0), UoA 1 (34.0), UoA 1 (33.0), UoA 1 (29.0)
# The most frequent funder is: Economic and Social Research Council [GBR](61). The second most is: Engineering and Physical Sciences Research Council [GBR](43).
# The most frequent country beneficiary is : GBR(177). The second most is: NLD(34).
# The most frequent regional beneficiary is : global (15). The second most is: europe (9).
# The five most common interdisciplinarities are: Law And Legal Studies; Human Society (29), Human Society; Law And Legal Studies (29), Human Society; Built Environment And Design (26), Built Environment And Design; Human Society (26), Human Society; Philosophy And Religious Studies (25).
# ...
