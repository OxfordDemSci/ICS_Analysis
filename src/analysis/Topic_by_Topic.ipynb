# %%
from helpers.topic_by_topic import make_topic_file,\
                                   make_figure_output
make_topic_file()

# %%
make_figure_output('2.')
# Out:
# We can directly DOI match:  0.617
# DOI returns:  10448
# We can directly ISBN match:  0.639
# ISBN returns:  3216
# Beginning to make the cluster figure for cluster:  2.
# Making the UoA sub-figure for cluster:  2.
# Making the WC sub-figure for cluster:  2.
# Making the Sankey sub-figure for cluster:  2.
# Making the choropleth sub-figure for cluster:  2.
# Making the Funder sub-figure for cluster:  2.
# Making the Interdisciplinarity sub-figure for cluster:  2.
# Saving figure for cluster:  2.

# %%
make_figure_output('9.')
# Out:
# We can directly DOI match:  0.617
# DOI returns:  10448
# We can directly ISBN match:  0.639
# ISBN returns:  3216
# Beginning to make the cluster figure for cluster:  9.
# Making the UoA sub-figure for cluster:  9.
# Making the WC sub-figure for cluster:  9.
# Making the Sankey sub-figure for cluster:  9.
# Making the choropleth sub-figure for cluster:  9.
# Making the Funder sub-figure for cluster:  9.
# Making the Interdisciplinarity sub-figure for cluster:  9.
# Saving figure for cluster:  9.

# %%
make_figure_output('10.')
# Out:
# We can directly DOI match:  0.617
# DOI returns:  10448
# We can directly ISBN match:  0.639
# ISBN returns:  3216
# Beginning to make the cluster figure for cluster:  10.
# Making the UoA sub-figure for cluster:  10.
# Making the WC sub-figure for cluster:  10.
# Making the Sankey sub-figure for cluster:  10.
# Making the choropleth sub-figure for cluster:  10.
# Making the Funder sub-figure for cluster:  10.
# Making the Interdisciplinarity sub-figure for cluster:  10.
# Saving figure for cluster:  10.
