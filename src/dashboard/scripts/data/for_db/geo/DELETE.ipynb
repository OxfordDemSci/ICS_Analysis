# %%
import geopandas as gpd

world = gpd.read_file("world_med.geo.json")
pc = gpd.read_file("postcode_areas.gpkg", layer="postcode_areas")
world
# Out:
#     iso_a2  su_dif iso_a3   iso  \
# 0       CU       0    CUB   192
# 1       DO       0    DOM   214
# 2       NI       0    NIC   558
# 3       GT       0    GTM   320
# 4       MF       0    MAF   663
# ..     ...     ...    ...   ...
# 231     RU       0    RUS   643
# 232     UA       0    UKR   804
# 233     MV       0    MDV  None
# 234     MU       0    MUS  None
# 235     SC       0    SYC  None
#
#                                               geometry
# 0    MULTIPOLYGON (((-81.83745 23.16304, -81.57544 ...
# 1    POLYGON ((-71.76831 18.03916, -71.76377 18.203...
# 2    POLYGON ((-83.15752 14.99307, -83.18535 14.956...
# 3    POLYGON ((-92.23516 14.54541, -92.20903 14.571...
# 4    POLYGON ((-63.01118 18.06895, -63.12305 18.068...
# ..                                                 ...
# 231  MULTIPOLYGON (((47.98301 45.48823, 47.96768 45...
# 232  MULTIPOLYGON (((35.02285 45.70098, 35.26016 45...
# 233  MULTIPOLYGON (((72.89986 7.10625, 72.90403 7.1...
# ...

# %%
pc.to_file("geodata.gpkg", layer="postcode_areas", driver="GPKG")
world.to_file("geodata.gpkg", layer="world", driver="GPKG")
